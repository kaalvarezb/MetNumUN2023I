# %% [markdown]
# **Linkedin**
#
# https://www.linkedin.com/in/tatiana-alvarez-baez-86a2b9223
#
# ![image_2023-03-08_081548996.png](data:image/png;base64,...)

# %% [markdown]
# **Python 101 for Data Science**
#
# https://courses.cognitiveclass.ai/certificates/2b4cbe72015044d587c54578deaaa87a
#
# ![image_2023-03-07_224612130.png](data:image/png;base64,...)

# %% [markdown]
# **Data Analysis with Python**
#
# https://courses.cognitiveclass.ai/certificates/4a74e9f7172c4d85a9532d565f81522c
#
# ![Screenshot 2023-03-07 225120.png](data:image/png;base64,...)

# %% [markdown]
# **Data Visualization with Python**
#
# https://courses.cognitiveclass.ai/certificates/ab077e2b34e0447eaf68e0baa5679386
#
# ![Screenshot 2023-03-07 225146.png](data:image/png;base64,...)
